# %%
import random

# %%
#The game mechanics
def throw(player_choice):
    computer_choice = random.randint(1,5)
    computer_choice_word = ""
    result = ""
    
    if computer_choice == 1:
        computer_choice_word = "Scissors"
        if player_choice == 3 or player_choice == 5:
            result = """YOU WIN! :)"""
        else:
            result = """YOU LOOSE :("""
    
    elif computer_choice == 2:
        computer_choice_word = "Paper"
        if player_choice == 1 or player_choice == 4:
            result = """YOU WIN! :)"""
        else:
            result = """YOU LOOSE :("""
    
    elif computer_choice == 3:
        computer_choice_word = "Rock"
        if player_choice == 2 or player_choice == 5:
            result = """YOU WIN! :)"""
        else:
            result = """YOU LOOSE :("""
    
    elif computer_choice == 4:
        computer_choice_word = "Lizard"
        if player_choice == 1 or player_choice == 3:
            result = """YOU WIN! :)"""
        else:
            result = """YOU LOOSE :("""
        
    elif computer_choice == 5:
        computer_choice_word = "Spock"
        if player_choice == 2 or player_choice == 4:
            result = """YOU WIN! :)"""
        else:
            result = """YOU LOOSE :("""
        

    if player_choice == computer_choice:
        result = """IT'S A DRAW :|"""

    print(f"""\nComputer played {computer_choice_word}""") 
    draw_icon(computer_choice)
    print(result)
    return computer_choice_word, result

# %%
#A visual representation of the player's selection
def draw_icon(choice):
    if choice == 1 or choice == "Scissors":
        print("""
                    _______
                ---'   ____)____
                          ______)
                       __________)
                      (____)
                ---.__(___)
                \n""")
        
    elif choice == 2 or choice == "Paper":
        print("""
                    ________
                ---'    ____)____
                           ______)
                          _______)
                         _______)
                ---.__________)
                \n""")
        
    elif choice == 3 or choice == "Rock":
        print("""
                    _______
                ---'   ____)
                      (_____)
                      (_____)
                      (____)
                ---.__(___)
                \n""")
        
    elif choice == 4 or choice == "Lizard":
        print("""
                --------...._____
                        _________)
                -.     /
                  \    \__
                   *-..___)
                \n""")
        
    elif choice == 5 or choice == "Spock":
        print("""
                    ⌒
                  ⌒| |    ◜﹆◜﹆
                 | || |  / // /
                 |_|| | /-//=/
                 | || |/ // /
                 ( || | // /
                 |         .______
                 |           ____ )
                 |         /
               \n""")
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\ '
# <>:34: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\jsunw\AppData\Local\Temp\ipykernel_26516\1292690955.py:34: SyntaxWarning: invalid escape sequence '\ '
#   print("""

# %%
def play():
    print("""\n
        -----------------------------------------------------
        WELCOME TO THE ROCK-PAPER-SCISSORS-LIZARD-SPOCK GAME!
        -----------------------------------------------------

        1: Scissors (cuts paper & decapitates lizard)
        2: Paper (covers rock & disproves Spock)
        3: Rock (crushes lizard & scissors)
        4: Lizard (poisons Spock & eats paper)
        5: Spock (smashes scissors & vaporizes rock)
        \n""")
    player_choice = ""
    player_input = int(input("""\n
        Please enter the number for your selection: """))
    if player_input == 1:
        player_choice = "Scissors"
        
    elif player_input == 2:
        player_choice = "Paper"

    elif player_input == 3:
        player_choice = "Rock"

    elif player_input == 4:
        player_choice = "Lizard"

    elif player_input == 5:
        player_choice = "Spock"

    print(f"""\nYou played {player_choice}""")
    draw_icon(player_choice)
    throw(player_input)

# %%
play()
# Out:
#         -----------------------------------------------------
#         WELCOME TO THE ROCK-PAPER-SCISSORS-LIZARD-SPOCK GAME!
#         -----------------------------------------------------
#
#         1: Scissors (cuts paper & decapitates lizard)
#         2: Paper (covers rock & disproves Spock)
#         3: Rock (crushes lizard & scissors)
#         4: Lizard (poisons Spock & eats paper)
#         5: Spock (smashes scissors & vaporizes rock)
#         Please enter the number for your selection:  3
# You played Rock
#
#                     _______
#                 ---'   ____)
#                       (_____)
#                       (_____)
#                       (____)
#                 ---.__(___)
#
#
#
# Computer played Lizard
#
#                 --------...._____
#                         _________)
#                 -.     /
#                   \    \__
#                    *-..___)
#
#
# YOU WIN! :)
